# %% [markdown]
# <a href="https://colab.research.google.com/github/qfaizan401/TensorFlow-Certification-Course1/blob/master/week1/hello_world_to_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Say Hello to ML.**
# This is the simplest ANN with only one layer and one neuron(unit) init. It figures out the relationship between X and Y. Let say:
# *   X = -1, 0, 1, 2, 3, 4
# *   Y = -3, -1, 1, 3, 5, 7
# ---
# Can you find the relationship between X and Y?
#
# > It can be difficult to predict the relation(equation) between any numbers. You have to do some Maths to figure out rules that have to be programmed.
#
# This is the point where the traditional programming paradigm does not help us out. Because we can not make rules for every real-life problem or scenario.
# ![image.png](data:image/png;base64,...)
#
# So now move to ML which say:
# ![image.png](data:image/png;base64,...)
#
# > You saw that the traditional paradigm of expressing rules in a coding language may not always work to solve a problem. As such, scenarios such as Computer Vision are very difficult to solve with rules-based programming. Instead, if we feed a computer with enough data that we describe (or label) as what we want it to recognize, given that computers are really good at processing data and finding patterns that match, then we could potentially ‘train’ a system to solve a problem.

# %% [markdown]
# The Relationship between X and Y is:
#
# > **Y = 2X-1**
#
#
# ---
#
# So if X=19 then Y=??

# %% [markdown]
# **Traditional Programming**

# %%
x = 19
y = (2*x)-1 # We define our rule here
print(y)
# Out:
# 37

# %% [markdown]
# **ML Programming**

# %% [markdown]
# First we perpare our dataset

# %%
import numpy as np
x_train = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
y_train = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0])

# %% [markdown]
# Now we create our basic ANN

# %%
import keras

# %%
model = keras.Sequential([keras.layers.Dense(units=1,
                                            activation='relu',
                                            input_shape=[1])])

# %% [markdown]
# Here we compile our model

# %%
model.compile(optimizer='sgd',
              loss='mean_squared_error')

# %% [markdown]
# Finally we train our model. Here we're asking the model to figure out how to fit the X values to the Y values.

# %%
model.fit(x=x_train,y=y_train,epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 416ms/step - loss: 5.7544
# Epoch 2/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9411
# Epoch 3/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3059
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8037
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4065
# Epoch 6/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0923
# Epoch 7/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8434
# Epoch 8/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6462
# Epoch 9/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4897
# Epoch 10/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3653
# Epoch 11/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2664
# Epoch 12/1000
# ...

# %% [markdown]
# Now our model is trained we the fun part is the perdiction that our model make.

# %%
perdicted_value = model.predict([19])
print(perdicted_value)
# Out:
# [[36.180832]]
